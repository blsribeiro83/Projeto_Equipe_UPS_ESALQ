# %%
## importação
import pandas as pd

# %%
VALE3 = pd.read_csv("data/raw/VALE3.csv",sep=",")

# %%
VALE3
# Out:
#             Date  Price   Open   High    Low     Vol. Change %
# 0     04/20/2020  31.72  32.32  32.32  31.55   28.90M   -3.50%
# 1     04/17/2020  32.87  32.79  33.04  32.29   23.53M    2.91%
# 2     04/16/2020  31.94  32.72  32.86  31.40   24.26M   -0.99%
# 3     04/15/2020  32.26  32.50  32.79  31.83   28.69M   -3.01%
# 4     04/14/2020  33.26  34.08  34.36  33.24   24.64M   -0.09%
# ...          ...    ...    ...    ...    ...      ...      ...
# 4995  02/02/2000   1.72   1.85   1.85   1.70    1.17M   -6.01%
# 4996  02/01/2000   1.83   1.83   1.83   1.83  111.60K   -2.14%
# 4997  01/28/2000   1.87   1.87   1.87   1.87  159.01K    0.00%
# 4998  01/27/2000   1.87   1.89   1.89   1.87  517.39K    0.54%
# 4999  01/26/2000   1.86   1.86   1.86   1.86  149.04K   -0.53%
#
# [5000 rows x 7 columns]

# %%
VALE3['Open'].describe()
# Out:
# count    5000.000000
# mean       16.912064
# std        10.596322
# min         1.350000
# 25%         8.027500
# 50%        17.730000
# 75%        23.920000
# max        45.270000
# Name: Open, dtype: float64
